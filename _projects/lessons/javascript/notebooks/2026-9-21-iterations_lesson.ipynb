# %% [raw]
# ---
# layout: post
# categories: [JavaScript, Iterations]
# assignment: true
# assignment_submission_type: code
# assignment_creator_uids:
#   - "CtNGit"
#   - "sathvik2020"
# lesson_language: JavaScript
# lesson_topic: Iterations
# lesson_source: CS111
# lesson_type: lesson
# microblog: true
# codemirror: true
# title: Iterations
# description: An intro to iterations using Code Runner
# permalink: /js/iterations
# author: Casey Nguyen, Sathvik Yadlapalli
# ---

# %% [markdown]
# ## 1. LxD Cycle Process
#
# **Empathize:** Beginners often copy and paste the same line five times instead of looping, and then get stuck when the loop runs one time too many or too few, or never stops. Off-by-one mistakes and infinite loops are the two errors students hit first.
#
# **Define:**
# - **POV:** JavaScript students need to see a loop as "start, check, change" because every loop, for or while, is built from those three parts and a missing part causes the bug.
# - **Learning Goal:** Students will write `for`, `for...in`, and `while` loops, loop over arrays and objects, and control where a loop starts, stops, and how it counts.
#
# **Ideate:**
# - **HMW Question:** How might we get students to ask "when does this stop?" before they run a loop?
# - **HMW Question:** How might we show that a `for` loop and a `while` loop are the same idea written two ways?
# - **Activity:** Fix a broken loop, loop over fruits and personal info, grow a vine with a `while` loop, answer the MCQ, then build a sum with a loop.
#
# **Prototype & Test:** _Lesson authors: add what happened in your trial run and what you changed._

# %% [markdown]
# ---
#
# ## 2. Lesson Plan
#
# **Learning Objective:** Use iteration to repeat code, and choose between a `for` loop and a `while` loop.
#
# **Success Criteria:** You can name the initialization, condition, and increment of a loop, predict how many times it runs, loop through an array or object, and avoid an infinite loop.
#
# ### Tech Talk (5 minutes)
#
# An **iteration** repeats a block of code. Instead of writing `console.log` five times, you write it once inside a loop.
#
# Every loop needs three things:
#
# 1. **A start:** where the counter begins
# 2. **A condition:** checked before every pass. If it is `true`, the loop runs again; if `false`, it stops
# 3. **A change:** something that moves the counter toward the end
#
# ```javascript
# for (let i = 1; i <= 5; i++) {   // start; condition; change
#     console.log(i);
# }
#
# let count = 1;                   // start
# while (count <= 5) {             // condition
#     console.log(count);
#     count++;                     // change
# }
# ```
#
# Both loops print 1 to 5. Use `for` when you know how many times to repeat, and `while` when you only know the rule for stopping.
#
# If the change is missing, the condition never becomes false and you get an **infinite loop**.

# %% [markdown]
# ---
#
# ## 3. Reference Guide
#
# ### Key Vocabulary
#
# <br>
#
# | Term               | Definition                                        | Example                  |
# |--------------------|---------------------------------------------------|--------------------------|
# | **Iteration**      | One pass through the body of a loop.              | `i` goes 1, 2, 3...      |
# | **Initialization** | Sets the counter once, before the loop starts.    | `let i = 0`              |
# | **Condition**      | Checked before each pass. `false` ends the loop.  | `i < 5`                  |
# | **Increment**      | Updates the counter after each pass.              | `i++` or `i += 2`        |
# | **Infinite loop**  | A loop whose condition never becomes false.       | `while (true) { }`       |
# | **Key**            | The name of a property in an object.              | `name` in `{name: "Casey"}` |
#
# ### Loop Types
#
# | Loop | Use it when | Example |
# |------|-------------|---------|
# | `for (init; cond; inc)` | You know how many times to repeat | `for (let i = 0; i < 5; i++)` |
# | `for (let key in obj)` | You want every key of an object | `for (let key in person)` |
# | `while (cond)` | You only know when to stop | `while (counter < 5)` |
#
# ### Picking a Loop
#
# - **Repeat a set number of times** → `for`
# - **Go through every item in an array** → `for` with `i < array.length`
# - **Go through every key of an object** → `for...in`
# - **Repeat until something changes** → `while`

# %% [markdown]
# ---
#
# ## 4. Code Examples
#
# ### A. Simple: The Three Parts of a for Loop
#
# ```javascript
# for (initialization; condition; increment) {
#     // Code to execute
# }
# ```
#
# - **Initialization:** sets up a counter variable and runs once at the beginning.
# - **Condition:** checked before each iteration. If true the loop continues; if false it ends.
# - **Increment:** updates the counter after each iteration.
#
# This loop has a syntax error. Find it and fix it.

# %%
# %%js
# // CODE_RUNNER: Run the loop, then fix the syntax error
#
# for (let i = 1, i <= 5; i++) {
#     console.log(i);
# }

# %% [markdown]
# ### B. Arrays: Loop Through Every Item
#
# A `for` loop can visit every element of an array using the index `i`. The condition `i < fruits.length` stops the loop after the last item.

# %%
# %%js
# // CODE_RUNNER: Run the loop, then add two of your own fruits to the array and run it again
#
# let fruits = ["Apple", "Orange", "Strawberry"];
#
# for (let i = 0; i < fruits.length; i++) {
#     console.log(fruits[i]);
# }

# %% [markdown]
# ### C. Objects: Loop Through Keys and Values
#
# `for...in` goes over each **key** of an **object**, and `personInfo[key]` gets its **value**.

# %%
# %%js
# // CODE_RUNNER: Run the loop, then change the values to your personal info
#
# const personInfo = { // Define an object
#     name: "Casey",
#     age: 14,
#     city: "San Diego",
#     occupation: "Del Norte High School Student"
# };
#
# for (let key in personInfo) { // Notice we are using for... in... instead of for... of...
#     console.log(key + ": " + personInfo[key]);
# }

# %% [markdown]
# ### D. while Loops
#
# A **`while` loop** repeats a block of code **as long as a condition is true**. It is best when you don't know how many times something should run, only the rule for when to stop.
#
# A `while` loop always includes:
#
# - **A starting value**
# - **A condition** checked before each pass
# - **A change** inside the loop that eventually makes the condition false
#
# If the condition never becomes false, the loop runs forever.

# %%
# %%js
# // CODE_RUNNER: Run the loop, then change the starting value, the condition, and the increment
#
# let counter = 0;
#
# while (counter < 5) {
#   console.log("The counter is:", counter);
#   counter += 1;
# }

# %% [markdown]
# Try experimenting with:
#
# - Changing the starting value
# - Changing the condition
# - Changing the increment (e.g., `counter += 2`)
# - Making it count down instead of up

# %% [markdown]
# ### E. Complex: Growing Vine
#
# Each pass makes the vine one 🌿 longer, so the loop variable controls how much is printed.

# %%
# %%js
# // CODE_RUNNER: Run the loop to see the growing vine, then make it shrink for a challenge
#
# let length = 1;
#
# while (length <= 10) {
#   console.log("🌿".repeat(length));
#   length += 1;
# }

# %% [markdown]
# Try experimenting with:
#
# - Changing the maximum length
# - Making the vine shrink instead of grow
# - Replacing the emoji with a different one
# - Increasing the growth rate (e.g., `length += 2`)

# %% [markdown]
# ---
#
# ## 5. Hacks & Practice Tasks
#
# ### Prepare your submission IPYNB
#
# 1. Create a new notebook in your portfolio homework area: `_notebooks/homework`.
# 2. Add one raw cell at the top with the frontmatter:
#
# ```raw
# ---
# layout: post
# codemirror: true
# title: Iterations HW
# categories: [JavaScript]
# lesson_language: JavaScript
# lesson_topic: Iterations HW
# lesson_part: interactive
# lesson_type: lesson
# permalink: /js/iterations-hw
# author: yourGithubID
# ---
# ```
#
# 3. Add code cells for the Popcorn Hack and the Homework Hack. Make sure every cell runs with visible output.
# 4. Submit the link to your published page at the bottom of this page, and paste this in the description box:
#
# ```text
# Lesson: JavaScript Iterations
# MCQ: <paste the copied result line, such as 3/4 | answers: A,C,B,A>
# Popcorn: countdown loop runs and prints
# Homework: sum loop with n = <your n>
# Homework: sum printed = <value>
# ```
#
# ### Submission Safety Rules (Read First)
#
# - Run each cell and leave the output showing.
# - Use your own values, not the sample answer.
# - Include your MCQ score.
# - Use `##` headings or smaller.

# %% [markdown]
# ### Popcorn Hack (In-Class)
#
# 2-minute challenge: write a loop that counts **down** from 10 to 1, then prints "Liftoff!" once.
#
# 1. Start the counter at 10
# 2. Keep looping while it is at least 1
# 3. Decrease it by 1 each pass
# 4. After the loop, print "Liftoff!"

# %%
# %%js
# // CODE_RUNNER: Finish the countdown loop, then run it
#
# let countdown = 10;
#
# // Write your while loop here
#
#
# console.log("Liftoff!");

# %% [markdown]
# ### MCQ Check
#
# 4 questions, one at a time. Answer, check, then go to the next one. At the end, copy the score line into your submission notes.

# %% [markdown]
# <style>
# .mcq-card { border: 1px solid rgba(127, 127, 127, 0.45); border-radius: 10px; padding: 1rem 1.25rem; max-width: 46rem; }
# .mcq-card .mcq-progress { font-size: 0.85rem; opacity: 0.75; margin: 0 0 0.35rem; }
# .mcq-card .mcq-question { font-weight: 600; margin: 0 0 0.6rem; }
# .mcq-card pre { margin: 0 0 0.75rem; overflow-x: auto; }
# .mcq-card .mcq-choice { display: block; margin: 0.4rem 0; cursor: pointer; }
# .mcq-card .mcq-feedback { margin: 0.75rem 0 0; }
# .mcq-card .mcq-buttons { margin-top: 0.9rem; }
# .mcq-card button { padding: 0.45rem 1rem; border-radius: 6px; cursor: pointer; margin-right: 0.5rem; }
# .mcq-card .mcq-score { font-size: 1.1rem; font-weight: 700; margin: 0 0 0.5rem; }
# .mcq-card .mcq-result input { width: 100%; max-width: 30rem; padding: 0.4rem; font-family: ui-monospace, monospace; margin: 0.4rem 0; display: block; }
# </style>
# <div class="mcq-card" id="mcq-js-iterations"></div>
# <script>
# (function () {
#   var data = [
#     {"q": "How many times does this loop print?", "code": "for (let i = 0; i < 5; i++) {\n  console.log(i);\n}", "choices": ["4 times", "5 times", "6 times", "It never stops"], "answer": 1, "ref": "Section 2", "why": "i takes the values 0, 1, 2, 3, 4. When i becomes 5 the condition i < 5 is false, so the loop ends."},
#     {"q": "What is wrong with this loop?", "code": "let x = 0;\nwhile (x < 3) {\n  console.log(x);\n}", "choices": ["The condition should be x <= 3", "It never changes x, so it is an infinite loop", "console.log cannot be used in a while loop", "Nothing, it prints 0, 1, 2"], "answer": 1, "ref": "Section 4D", "why": "x stays 0, so x < 3 is always true. A while loop needs a change inside it, such as x++."},
#     {"q": "Which loop is the best fit for visiting every key in an object?", "choices": ["for (let i = 0; i < 5; i++)", "while (true)", "for (let key in obj)", "for (;;)"], "answer": 2, "ref": "Section 3", "why": "for...in hands you each key of the object one at a time."},
#     {"q": "What does this loop print?", "code": "let n = 10;\nwhile (n > 0) {\n  n -= 4;\n}\nconsole.log(n);", "choices": ["2", "0", "-2", "10"], "answer": 2, "ref": "Section 4D", "why": "n goes 10, 6, 2, then -2. At -2 the condition n > 0 is false, so the loop stops and -2 is printed."}
#   ];
#   var root = document.getElementById("mcq-js-iterations");
#   if (!root) return;
#   var index = 0;
#   var correct = 0;
#   var picks = [];
#
#   function clear() { while (root.firstChild) { root.removeChild(root.firstChild); } }
#
#   function showQuestion() {
#     clear();
#     var item = data[index];
#     var progress = document.createElement("p");
#     progress.className = "mcq-progress";
#     progress.textContent = "Question " + (index + 1) + " of " + data.length;
#     root.appendChild(progress);
#     var question = document.createElement("p");
#     question.className = "mcq-question";
#     question.textContent = item.q;
#     root.appendChild(question);
#     if (item.code) {
#       var pre = document.createElement("pre");
#       var code = document.createElement("code");
#       code.textContent = item.code;
#       pre.appendChild(code);
#       root.appendChild(pre);
#     }
#     var form = document.createElement("form");
#     item.choices.forEach(function (choice, j) {
#       var label = document.createElement("label");
#       label.className = "mcq-choice";
#       var input = document.createElement("input");
#       input.type = "radio";
#       input.name = "js-iter-q" + index;
#       input.value = j;
#       label.appendChild(input);
#       label.appendChild(document.createTextNode(" " + "ABCD".charAt(j) + ". " + choice));
#       form.appendChild(label);
#     });
#     var feedback = document.createElement("p");
#     feedback.className = "mcq-feedback";
#     feedback.setAttribute("aria-live", "polite");
#     var buttons = document.createElement("div");
#     buttons.className = "mcq-buttons";
#     var check = document.createElement("button");
#     check.type = "submit";
#     check.textContent = "Check answer";
#     buttons.appendChild(check);
#     form.appendChild(feedback);
#     form.appendChild(buttons);
#     form.addEventListener("submit", function (event) {
#       event.preventDefault();
#       var picked = form.querySelector("input[name='js-iter-q" + index + "']:checked");
#       if (!picked) { feedback.textContent = "Pick an answer first."; return; }
#       var value = Number(picked.value);
#       picks.push("ABCD".charAt(value));
#       if (value === item.answer) {
#         correct++;
#         feedback.textContent = "Correct. " + item.why;
#       } else {
#         feedback.textContent = "Not quite. The answer is " + "ABCD".charAt(item.answer) + ". " + item.why + " (Review " + item.ref + ".)";
#       }
#       var inputs = form.querySelectorAll("input");
#       for (var k = 0; k < inputs.length; k++) { inputs[k].disabled = true; }
#       buttons.removeChild(check);
#       var next = document.createElement("button");
#       next.type = "button";
#       next.textContent = index + 1 < data.length ? "Next question" : "See my score";
#       next.addEventListener("click", function () {
#         index++;
#         if (index < data.length) { showQuestion(); } else { showScore(); }
#       });
#       buttons.appendChild(next);
#     });
#     root.appendChild(form);
#   }
#
#   function showScore() {
#     clear();
#     var score = document.createElement("p");
#     score.className = "mcq-score";
#     score.textContent = "Score: " + correct + " / " + data.length;
#     root.appendChild(score);
#     var line = document.createElement("div");
#     line.className = "mcq-result";
#     var hint = document.createElement("label");
#     hint.textContent = "Paste this line into your submission notes:";
#     var box = document.createElement("input");
#     box.type = "text";
#     box.readOnly = true;
#     box.value = "MCQ Iterations: " + correct + "/" + data.length + " | answers: " + picks.join(",");
#     var copy = document.createElement("button");
#     copy.type = "button";
#     copy.textContent = "Copy result";
#     copy.addEventListener("click", function () {
#       box.select();
#       if (navigator.clipboard) { navigator.clipboard.writeText(box.value); }
#       copy.textContent = "Copied";
#       setTimeout(function () { copy.textContent = "Copy result"; }, 1500);
#     });
#     var again = document.createElement("button");
#     again.type = "button";
#     again.textContent = "Try again";
#     again.addEventListener("click", function () { index = 0; correct = 0; picks = []; showQuestion(); });
#     line.appendChild(hint);
#     line.appendChild(box);
#     line.appendChild(copy);
#     line.appendChild(again);
#     root.appendChild(line);
#   }
#
#   showQuestion();
# })();
# </script>

# %% [markdown]
# ### Homework Hack: Challenge Iteration
#
# **Task:** Use a loop to calculate the sum of all the numbers from 1 to `n`. Test it with `n = 5`, then try a different `n`.
#
# Do not use a function. Set `n` as a variable, and use a loop to add each number to `sum`.
#
# **Hint:** Use `n` in your condition, and change the value of `n` to change the upper limit you are adding up to. For `n = 5` the answer is `1 + 2 + 3 + 4 + 5 = 15`.
#
# **Solution Skeleton:**

# %%
# %%js
# // CODE_RUNNER: Finish the loop to add up 1 to n, then run it with n = 5 and a value of your choice
#
# let n = 5;
# let sum = 0;
#
# // Write your loop here
#
#
# console.log("The sum of 1 to " + n + " is " + sum);

# %% [markdown]
# ---
#
# ## 6. Grading Plan (1 Point Total)
#
# | Part | Points | What earns the points |
# | --- | --- | --- |
# | Popcorn | 0.2 | Countdown loop counts 10 to 1, prints "Liftoff!" once, and the cell runs. |
# | MCQ | 0.2 | 4 correct. 0.15 for 3, 0.1 if every question was answered. |
# | Homework: loop | 0.3 | Uses a `for` or `while` loop with `n` in the condition, and no function. |
# | Homework: sum | 0.3 | Prints the correct sum for `n = 5` (15) and for your own `n`. |
# | **Total** | **1.0** | |
#
# ### Quick Validation Checklist
#
# - Every cell runs and shows output.
# - MCQ score in the notes.
# - The countdown loop changes its counter so it stops.
# - The sum uses a loop and no function.
#
# ---
#
# ## 7. Lesson Revisions & Feedback Evidence
#
# **Feedback Received:** _Lesson authors: what your peers said in the practice run._
#
# **Revision Made:** _Lesson authors: what you changed because of it._
